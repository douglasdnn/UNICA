# %%
from gemini import gemini as gemini

# %%
minha_pergunta = "Quando o Brasil foi descoberto?"

print(f"Enviando pergunta: '{minha_pergunta}'\n")

# Chama a função
resposta_obtida = gemini.perguntar(minha_pergunta)
# Out:
# Enviando pergunta: 'Quando o Brasil foi descoberto?'
#
# O Brasil foi oficialmente "descoberto" para a Europa em **22 de abril de 1500**, por Pedro Álvares Cabral.  É importante ressaltar que a expressão "descoberto" é problemática, pois já existiam povos indígenas vivendo no território há milhares de anos.
