# %%
import sqlite3

# Conectando ao banco de dados
conn = sqlite3.connect('urcaciv.db')
cursor = conn.cursor()

# Atualizando os campos pet e resumo para NULL onde id = 35
cursor.execute("""
    UPDATE STM1CIV
    SET pet = NULL, resumo = NULL
    WHERE id = 35
""")

conn.commit()
conn.close()
