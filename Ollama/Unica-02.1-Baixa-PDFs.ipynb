# %%
# Importações e setup

#from selenium import webdriver
from seleniumwire import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException, WebDriverException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException

#Bibliotecas de Sistema
from datetime import datetime
from datetime import timedelta
from datetime import date
from datetime import timezone
import time
import re
import csv
import os
import requests
import psutil
from bs4 import BeautifulSoup
from eproc_driver import eproc as eproc
import sqlite3
from pathlib import Path
import io
import pandas as pd
from contextlib import closing
from sympy import false
from pydoc import text
from sympy import true
import PyPDF2
import glob

#bibliotecas de Google Sheets
import gspread
from oauth2client.service_account import ServiceAccountCredentials

#bibliotecas de configuração
import pyotp
import configparser
import keyring

#bibliotecas de automação
import pyperclip
import pyautogui

#Bibliotecas de IA
from gemini import gemini as gemini
import ollama

#pasta_downloads = r"C:\Users\dodonin\Downloads"
pasta_downloads = r"D:\Douglas\Downloads"

# DEBUG, sim ou não
debug = False

# %%
# Definição de perfil e tipo de processo

scope = [
    'https://spreadsheets.google.com/feeds',
    'https://www.googleapis.com/auth/drive'
]

creds = ServiceAccountCredentials.from_json_keyfile_name('secret.json', scope)
client = gspread.authorize(creds)

spreadsheet = client.open_by_key("12eVCoiOYlW4oB-N-yCd5JPEqSDOGfON5IBN3AcvYGTQ")

control_sheet = spreadsheet.worksheet("Controle")
cell_b1 = control_sheet.cell(1, 2).value

perfil = control_sheet.cell(1, 2).value
tipo_processo = control_sheet.cell(2, 2).value

sheet = spreadsheet.worksheet(perfil)

#perfil = "SRD1CIV"
#perfil = "CAN1CIV"
#perfil = "GDO1CIV"
#perfil = "STM1CIV"
#perfil = "SRO2CR"
#perfil = "POA08FZFC"

print("Perfil escolhido:", perfil)
print("Tipo de Processo:", tipo_processo)
# Out:
# Perfil escolhido: SRD1CIV
# Tipo de Processo: EXECUÇÃO FISCAL

# %%
# Inicia o navegador, loga no perfil escolhido

if debug:
    print(f"[DEBUG] pasta_downloads: {pasta_downloads}")

navegador = eproc.novo_browser(pasta_downloads)

if debug:
    print("[DEBUG] Navegador iniciado.")

#configura variáveis
username = "dodonin"
password = keyring.get_password("eproc", username)
pyotop_code = "GJRGIYTCGBSGKYTEHE2TOZRUGFQTMMRQ"

#eproc.login_no_eproc_tj(navegador, username, password, pyotop_code)
eproc.login_no_eproc(navegador, username, password, pyotop_code)

if debug:
    print("[DEBUG] Login realizado.")

# Entra no perfil da Vara
eproc.entrar_no_perfil(navegador, perfil)

if debug:
    print(f"[DEBUG] Entrou no perfil: {perfil}")
# Out:
# Driver do Eproc importado
# Perfil carregado: SRD1CIV

# %%
# Define funções

def pega_tabela_pagina(dados_tabela):
    tabela = navegador.find_element(By.ID, "tabelaLocalizadores")
    linhas = tabela.find_elements(By.TAG_NAME, "tr")[1:]  # Ignora o cabeçalho
    lastpage = false
    while lastpage == false:
        for linha in linhas:
            # Aguarda o carregamento do tbody da tabela antes de processar as linhas
            WebDriverWait(navegador, 10).until(
                EC.presence_of_element_located((By.XPATH, "//table[@id='tabelaLocalizadores']/tbody"))
            )
            colunas = linha.find_elements(By.TAG_NAME, "td")
            if len(colunas) >= 4:
                # Pega as três primeiras colunas e também a última
                dados_tabela.append([
                    colunas[1].text.split('\n')[0],
                    colunas[2].text.split('\n')[0],
                    colunas[3].text.split('\n')[0],
                    colunas[-1].text.split('\n')[0]
                ])
            
            lastpage = true

def pega_ultima_peticao(navegador, num_processo):
    """
    Localiza a última petição ("PET") disponível no processo informado,
    captura a requisição real feita pelo navegador (Selenium Wire) para baixar o PDF
    e salva o arquivo localmente.

    Parâmetros:
        navegador     -> instância do Selenium Wire WebDriver já autenticada no eproc.
        num_processo  -> número do processo (será usado no nome do PDF).

    Retorna:
        (evento_id, caminho_pdf) se o download foi bem-sucedido.
        (None, None) caso não haja petição ou falha no download.
    """
    import os
    import requests
    from selenium.webdriver.common.by import By
    import glob

    # === 1. Coleta todos os eventos do processo ===
    documentos_eventos = []
    eventos = navegador.find_elements(By.CLASS_NAME, "td-evento")

    for evento in eventos:
        # ID do elemento que identifica o documento
        doc_id = evento.get_dom_attribute("id")

        # Sobe até a linha da tabela e pega o número do evento
        tr_element = evento.find_element(By.XPATH, "./ancestor::tr")
        evento_id = tr_element.find_element(By.XPATH, './td[2]').text
        evento_id = ''.join(filter(str.isdigit, evento_id))  # mantém só números

        # Verifica se é documento tipo PET (Petição)
        try:
            infra_link = evento.find_element(By.XPATH, ".//*[contains(@class, 'infraLinkDoc')]")
            data_nome = infra_link.get_attribute("data-nome")
        except Exception:
            data_nome = None

        documentos_eventos.append((doc_id, data_nome, evento_id))

    # === 2. Filtra apenas documentos do tipo PET que não tenham sido decididos ainda===
    documentos_eventos_filtrados = [item for item in documentos_eventos if item[1] and "PET" in item[1]]    
    despachos_eventos_filtrados = [item for item in documentos_eventos if item[1] and "DESPADEC" in item[1]]

    # Se houver despachos, filtra apenas petições com evento_id superior ao maior despacho
    if despachos_eventos_filtrados:
        maior_evento_despacho = max(int(item[2]) for item in despachos_eventos_filtrados)
        documentos_eventos_filtrados = [
            item for item in documentos_eventos_filtrados if int(item[2]) > maior_evento_despacho
        ]

    
    if not documentos_eventos_filtrados:
        erro = "Nenhuma petição encontrada."
        return erro, None
    
    # === 3. Pega a petição mais recente (maior evento_id) ===
    documentos_eventos_filtrados.sort(key=lambda x: int(x[2]), reverse=True)
    documento_requerido = documentos_eventos_filtrados[0]
    evento_id = documento_requerido[2]

    # Caminho onde o PDF será salvo
    caminho_pdf = os.path.join(pasta_downloads, f"{num_processo}.pdf")

    # Localiza o elemento do documento e o link
    elemento = navegador.find_element(By.ID, documento_requerido[0])
    link = elemento.find_element(By.XPATH, ".//*[contains(@class, 'infraLinkDoc')]")

    # Limpa histórico de requests para capturar apenas a próxima
    navegador.requests.clear()

    # Clica no link para gerar a requisição ao controlador.php
    link.click()
    
    # Aguarda o carregamento do preview/divBoxPreview para garantir que o clique gerou a requisição
    WebDriverWait(navegador, 10).until(
        EC.presence_of_element_located((By.ID, "divBoxPreview"))
    )
    time.sleep(2)  # Pequeno delay extra para garantir a requisição
    # Clica no botão "open-button" para abrir o documento em nova janela/aba
    # Vai para a aba que foi aberta
    if len(navegador.window_handles) > 1:
        navegador.switch_to.window(navegador.window_handles[-1])
    try:
        timestamp_download = datetime.now().isoformat()
        navegador.find_element(By.TAG_NAME, 'body').send_keys('\t\t\n')
        time.sleep(1)
    except Exception as e:
        print("Botão 'open-button' não encontrado ou erro ao clicar:", e)
    # Fecha a nova aba/janela aberta pelo botão "open-button"
    if len(navegador.window_handles) > 1:
        # Fecha todas as abas, menos a primeira
        while len(navegador.window_handles) > 1:
            navegador.switch_to.window(navegador.window_handles[-1])
            navegador.close()
        navegador.switch_to.window(navegador.window_handles[0])
    # === 4. Procura o PDF mais recente na pasta de downloads ===

    arquivos_pdf = glob.glob(os.path.join(pasta_downloads, "*.pdf"))
    if not arquivos_pdf:
        erro = "Nenhum PDF encontrado na pasta de downloads."        
        return erro, None

    # Encontra o PDF mais recente
    pdf_mais_recente = max(arquivos_pdf, key=os.path.getmtime)
    tempo_modificacao = os.path.getmtime(pdf_mais_recente)
    tempo_modificacao_dt = datetime.fromtimestamp(tempo_modificacao)
    tempo_diff = abs((tempo_modificacao_dt - datetime.fromisoformat(timestamp_download)).total_seconds())

    if tempo_diff <= 10:
        # Move o arquivo para o caminho_pdf
        os.makedirs(os.path.dirname(caminho_pdf), exist_ok=True)
        os.replace(pdf_mais_recente, caminho_pdf)
        print(f"PDF renomeado e salvo em: {caminho_pdf}")
        return None, caminho_pdf
    
    else:
        erro = f"PDF mais recente tem diferença de {tempo_diff:.2f} segundos da timestamp. Não será renomeado."
        return erro, None
    


def extrair_texto_pdf(caminho_pdf):
    with open(caminho_pdf, 'rb') as arquivo:
        leitor = PyPDF2.PdfReader(arquivo)
        texto = ""
        for pagina in leitor.pages:
            texto += pagina.extract_text()
    return texto

def pega_texto_documento(navegador, documento):
    WebDriverWait(navegador, 20).until(
        EC.presence_of_element_located((By.ID, documento))
    )
    # 1. Localizar o elemento pelo ID
    elemento = navegador.find_element(By.ID, documento)
    # 2. Criar ActionChains para executar o mouse over
    actions = ActionChains(navegador)
    # Rolar a página para o elemento antes de mover o mouse
    navegador.execute_script("arguments[0].scrollIntoView(true); window.scrollBy(0, -150);", elemento)
    # Faz o mouseover em cima do texto link infraLinkDocumento do elemento
    link_doc = elemento.find_element(By.XPATH, ".//*[contains(@class, 'infraLinkDoc')]")
    actions.move_to_element(link_doc).perform()
    # 3. Aguardar para o hover ter efeito
    time.sleep(5)
    
    # Verifica se há uma div com a classe 'divBoxPreview' visível na página
    overlays = navegador.find_elements(By.ID, "divBoxPreview")
    visiveis = [div for div in overlays if div.is_displayed()]

    conteudo = ""
    if visiveis:
        div = overlays[0]
        # Move o foco para a div
        ActionChains(navegador).move_to_element(div).click().perform()
        # Aguarda carregar o conteúdo (ajuste o tempo se necessário)
        time.sleep(1)
        # Seleciona o texto
        conteudo = navegador.find_element(By.ID, "divBoxPreview").text
        # Clica no botão de fechar o preview, se existir
        btn_close = navegador.find_element(By.ID, "divClosePreview")
        btn_close.click()    
        time.sleep(3)

    else:
        print("Erro ao recuperar o documento")
    return conteudo

def ollama_resumo(pedido):    
    pergunta_gemma = "Considere o seguinte pedido." \
    f"{pedido}" \
    "Resuma, da maneira mais objetiva possível, o pedido. Não mencione dados pessoais, como nomes, números de documento, números de processo, valores, etc. " \
    "O resumo deve ser genérico e breve (uma frase apenas, com o mínimo de palavras possível). " \
    "Se tiver mais de um pedido, retorne uma frase para cada um." \

    resumo = ollama.chat(
        model="cnmoro/gemma3-gaia-ptbr-4b:q8_0",
        messages=[{'role': 'user', 'content': f'{pergunta_gemma}'}],    
    )

    return(resumo['message']['content'])

def verifica_tipos_de_pedidos(pedido, lista_de_pedidos):

    print("========== Verificando se é um caso de uso conhecido... ==========")
    pergunta_gemma = "Considere a seguinte lista de pedidos:" \
    f"{lista_de_pedidos}" \
    f"É possível dizer que o pedido '{pedido}' pode ser adequadamente descrito por um item dessa lista?." \
    "Se sim, retorne APENAS o texto EXATO do resumo do pedido correspondente na lista. Se não, retorne APENAS o texto 'Não'."

    resumo = ollama.chat(
        model="cnmoro/gemma3-gaia-ptbr-4b:q8_0",
        messages=[{'role': 'user', 'content': f'{pergunta_gemma}'}],    
    )

    return(resumo['message']['content'])

def baixa_peticao_processo(navegador, processo):
    navegador.switch_to.default_content()
    eproc.entrar_no_processo(navegador, processo)

    with sqlite3.connect("urcaciv.db") as conn:
        erro, texto_peticao = pega_ultima_peticao(navegador, processo) 
    
    return erro, texto_peticao

# %%
def pega_proximo():
    try:
        # Pega o num_processo (coluna B) onde a coluna G está vazia
        records = sheet.get_all_records()
        num_processo = None

        for record in records:
            # Verifica se a coluna 'Texto da Petição' (coluna G/pet) está vazia
            if not record.get('Texto da Petição'):
                num_processo = record.get('Número do Processo')
                break

        if not num_processo:
            print("Nenhum processo pendente encontrado.")
            return

        erro, texto_peticao = baixa_peticao_processo(navegador, num_processo)

        if erro:
            print("Erro ao baixar petição:", erro)
            texto_peticao = "Erro"
            
            # Encontra a linha do processo e atualiza a coluna G
            cell = sheet.find(num_processo)
            if cell:
                sheet.update_cell(cell.row, 7, texto_peticao)  # Coluna G = 7
                print(f"Erro gravado na planilha para o processo {num_processo}")
        else:
            texto_extraido = extrair_texto_pdf(texto_peticao)

            # Remove espaços extras, múltiplas quebras de linha e espaços no início/fim
            texto_extraido = ' '.join(texto_extraido.split())    

            # Encontra a linha do processo e atualiza a coluna G
            cell = sheet.find(num_processo)
            if cell:
                sheet.update_cell(cell.row, 7, texto_extraido)  # Coluna G = 7
                print(f"Texto da petição gravado na planilha para o processo {num_processo}")
    
    except Exception as e:
        print(f"Erro na função pega_proximo: {e}")
        if 'num_processo' in locals() and num_processo:
            try:
                cell = sheet.find(num_processo)
                if cell:
                    sheet.update_cell(cell.row, 7, f"Erro: {str(e)}")
            except Exception as inner_e:
                print(f"Erro ao gravar erro na planilha: {inner_e}")

# %%
# Executa pega_proximo() enquanto houver registros com a coluna G vazia
contador = 0

# Primeiro, conta o total de registros pendentes
records = sheet.get_all_records()
total_pendentes = sum(1 for record in records if not record.get('Texto da Petição'))

print(f"Total de registros a processar: {total_pendentes}")

while True:
    records = sheet.get_all_records()
    
    # Verifica se ainda existem registros com a coluna 'Texto da Petição' vazia
    tem_pendente = False
    for record in records:
        if not record.get('Texto da Petição'):
            tem_pendente = True
            break
    
    if not tem_pendente:
        print("Todos os registros foram processados!")
        break
    
    # Executa pega_proximo()
    contador += 1
    print(f"Processando registro {contador}/{total_pendentes}...")
    pega_proximo()

print(f"Total de registros processados: {contador}")
# Out:
# Total de registros a processar: 329
# Processando registro 1/329...
# Página do processo 5000851-81.2020.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 1651.94 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000851-81.2020.8.21.0069
# Processando registro 2/329...
# Página do processo 5000850-23.2025.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 1672.98 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000850-23.2025.8.21.0069
# Processando registro 3/329...
# Página do processo 5000840-57.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000840-57.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000840-57.2017.8.21.0069
# Processando registro 4/329...
# Página do processo 5000837-24.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000837-24.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000837-24.2025.8.21.0069
# Processando registro 5/329...
# Página do processo 5000837-05.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000837-05.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000837-05.2017.8.21.0069
# Processando registro 6/329...
# Página do processo 5000831-17.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000831-17.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000831-17.2025.8.21.0069
# Processando registro 7/329...
# Página do processo 5000824-25.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000824-25.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000824-25.2025.8.21.0069
# Processando registro 8/329...
# Página do processo 5000823-79.2021.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000823-79.2021.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000823-79.2021.8.21.0069
# Processando registro 9/329...
# Página do processo 5000823-40.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000823-40.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000823-40.2025.8.21.0069
# Processando registro 10/329...
# Página do processo 5000817-77.2018.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000817-77.2018.8.21.0069
# Processando registro 11/329...
# Página do processo 5000793-44.2021.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000793-44.2021.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000793-44.2021.8.21.0069
# Processando registro 12/329...
# Página do processo 5000782-88.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000782-88.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000782-88.2016.8.21.0069
# Processando registro 13/329...
# Página do processo 5000779-21.2025.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000779-21.2025.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000779-21.2025.8.21.0069
# Processando registro 14/329...
# Página do processo 5000775-81.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000775-81.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000775-81.2025.8.21.0069
# Processando registro 15/329...
# Página do processo 5000771-54.2019.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 21.64 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000771-54.2019.8.21.0069
# Processando registro 16/329...
# Página do processo 5000769-74.2025.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000769-74.2025.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000769-74.2025.8.21.0069
# Processando registro 17/329...
# Página do processo 5000763-43.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000763-43.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000763-43.2020.8.21.0069
# Processando registro 18/329...
# Página do processo 5000749-83.2025.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000749-83.2025.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000749-83.2025.8.21.0069
# Processando registro 19/329...
# Página do processo 5000745-80.2024.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000745-80.2024.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000745-80.2024.8.21.0069
# Processando registro 20/329...
# Página do processo 5000745-46.2025.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 22.06 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000745-46.2025.8.21.0069
# Processando registro 21/329...
# Página do processo 5000739-78.2021.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000739-78.2021.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000739-78.2021.8.21.0069
# Processando registro 22/329...
# Página do processo 5000737-16.2018.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000737-16.2018.8.21.0069
# Processando registro 23/329...
# Página do processo 5000733-66.2024.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000733-66.2024.8.21.0069
# Processando registro 24/329...
# Página do processo 5000731-72.2019.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 43.66 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000731-72.2019.8.21.0069
# Processando registro 25/329...
# Página do processo 5000729-63.2023.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000729-63.2023.8.21.0069
# Processando registro 26/329...
# Página do processo 5000727-74.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000727-74.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000727-74.2015.8.21.0069
# Processando registro 27/329...
# Página do processo 5000727-35.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000727-35.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000727-35.2019.8.21.0069
# Processando registro 28/329...
# Página do processo 5000721-23.2022.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000721-23.2022.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000721-23.2022.8.21.0069
# Processando registro 29/329...
# Página do processo 5000713-46.2022.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000713-46.2022.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000713-46.2022.8.21.0069
# Processando registro 30/329...
# Página do processo 5000704-89.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000704-89.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000704-89.2019.8.21.0069
# Processando registro 31/329...
# Página do processo 5000700-57.2016.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000700-57.2016.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000700-57.2016.8.21.0069
# Processando registro 32/329...
# Página do processo 5000693-55.2022.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000693-55.2022.8.21.0069
# Processando registro 33/329...
# Página do processo 5000677-09.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000677-09.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000677-09.2019.8.21.0069
# Processando registro 34/329...
# Página do processo 5000673-98.2021.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000673-98.2021.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000673-98.2021.8.21.0069
# Processando registro 35/329...
# Página do processo 5000671-02.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000671-02.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000671-02.2019.8.21.0069
# Processando registro 36/329...
# Página do processo 5000665-97.2016.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000665-97.2016.8.21.0069
# Processando registro 37/329...
# Página do processo 5000664-73.2020.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000664-73.2020.8.21.0069
# Processando registro 38/329...
# Página do processo 5000659-85.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000659-85.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000659-85.2019.8.21.0069
# Processando registro 39/329...
# Página do processo 5000657-86.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000657-86.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000657-86.2017.8.21.0069
# Processando registro 40/329...
# Página do processo 5000647-76.2016.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000647-76.2016.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000647-76.2016.8.21.0069
# Processando registro 41/329...
# Página do processo 5000647-66.2022.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000647-66.2022.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000647-66.2022.8.21.0069
# Processando registro 42/329...
# Página do processo 5000641-64.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000641-64.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000641-64.2019.8.21.0069
# Processando registro 43/329...
# Página do processo 5000639-21.2024.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000639-21.2024.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000639-21.2024.8.21.0069
# Processando registro 44/329...
# Página do processo 5000637-17.2025.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000637-17.2025.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000637-17.2025.8.21.0069
# Processando registro 45/329...
# Página do processo 5000631-88.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000631-88.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000631-88.2017.8.21.0069
# Processando registro 46/329...
# Página do processo 5000631-83.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000631-83.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000631-83.2020.8.21.0069
# Processando registro 47/329...
# Página do processo 5000627-80.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000627-80.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000627-80.2019.8.21.0069
# Processando registro 48/329...
# Página do processo 5000623-48.2016.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000623-48.2016.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000623-48.2016.8.21.0069
# Processando registro 49/329...
# Página do processo 5000614-86.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000614-86.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000614-86.2016.8.21.0069
# Processando registro 50/329...
# Página do processo 5000613-33.2018.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000613-33.2018.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000613-33.2018.8.21.0069
# Processando registro 51/329...
# Página do processo 5000604-71.2018.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000604-71.2018.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000604-71.2018.8.21.0069
# Processando registro 52/329...
# Página do processo 5000603-52.2019.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000603-52.2019.8.21.0069
# Processando registro 53/329...
# Página do processo 5000603-42.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000603-42.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000603-42.2025.8.21.0069
# Processando registro 54/329...
# Página do processo 5000600-24.2024.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000600-24.2024.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000600-24.2024.8.21.0069
# Processando registro 55/329...
# Página do processo 5000599-39.2024.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000599-39.2024.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000599-39.2024.8.21.0069
# Processando registro 56/329...
# Página do processo 5000597-21.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000597-21.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000597-21.2014.8.21.0069
# Processando registro 57/329...
# Página do processo 5000591-67.2021.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000591-67.2021.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000591-67.2021.8.21.0069
# Processando registro 58/329...
# Página do processo 5000585-36.2016.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000585-36.2016.8.21.0069
# Processando registro 59/329...
# Página do processo 5000577-93.2015.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000577-93.2015.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000577-93.2015.8.21.0069
# Processando registro 60/329...
# Página do processo 5000577-54.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000577-54.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000577-54.2019.8.21.0069
# Processando registro 61/329...
# Página do processo 5000571-18.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000571-18.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000571-18.2017.8.21.0069
# Processando registro 62/329...
# Página do processo 5000571-13.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000571-13.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000571-13.2020.8.21.0069
# Processando registro 63/329...
# Página do processo 5000567-78.2017.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000567-78.2017.8.21.0069
# Processando registro 64/329...
# Página do processo 5000553-26.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000553-26.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000553-26.2019.8.21.0069
# Processando registro 65/329...
# Página do processo 5000552-12.2017.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000552-12.2017.8.21.0069
# Processando registro 66/329...
# Página do processo 5000543-84.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000543-84.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000543-84.2016.8.21.0069
# Processando registro 67/329...
# Página do processo 5000542-60.2020.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000542-60.2020.8.21.0069
# Processando registro 68/329...
# Página do processo 5000541-36.2024.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000541-36.2024.8.21.0069
# Processando registro 69/329...
# Página do processo 5000529-37.2015.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000529-37.2015.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000529-37.2015.8.21.0069
# Processando registro 70/329...
# Página do processo 5000528-76.2020.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000528-76.2020.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000528-76.2020.8.21.0069
# Processando registro 71/329...
# Página do processo 5000527-52.2024.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000527-52.2024.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000527-52.2024.8.21.0069
# Processando registro 72/329...
# Página do processo 5000521-89.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000521-89.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000521-89.2017.8.21.0069
# Processando registro 73/329...
# Página do processo 5000519-17.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000519-17.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000519-17.2020.8.21.0069
# Processando registro 74/329...
# Página do processo 5000517-81.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000517-81.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000517-81.2019.8.21.0069
# Processando registro 75/329...
# Página do processo 5000517-13.2021.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000517-13.2021.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000517-13.2021.8.21.0069
# Processando registro 76/329...
# Página do processo 5000515-53.2015.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000515-53.2015.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000515-53.2015.8.21.0069
# Processando registro 77/329...
# Página do processo 5000512-64.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000512-64.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000512-64.2016.8.21.0069
# Processando registro 78/329...
# Página do processo 5000507-76.2015.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000507-76.2015.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000507-76.2015.8.21.0069
# Processando registro 79/329...
# Página do processo 5000507-27.2025.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 21.67 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000507-27.2025.8.21.0069
# Processando registro 80/329...
# Página do processo 5000500-21.2014.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000500-21.2014.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000500-21.2014.8.21.0069
# Processando registro 81/329...
# Página do processo 5000499-36.2014.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000499-36.2014.8.21.0069
# Processando registro 82/329...
# Página do processo 5000495-62.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000495-62.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000495-62.2015.8.21.0069
# Processando registro 83/329...
# Página do processo 5000495-23.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000495-23.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000495-23.2019.8.21.0069
# Processando registro 84/329...
# Página do processo 5000495-18.2022.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000495-18.2022.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000495-18.2022.8.21.0069
# Processando registro 85/329...
# Página do processo 5000493-53.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000493-53.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000493-53.2019.8.21.0069
# Processando registro 86/329...
# Página do processo 5000493-14.2023.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000493-14.2023.8.21.0069
# Processando registro 87/329...
# Página do processo 5000489-89.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000489-89.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000489-89.2014.8.21.0069
# Processando registro 88/329...
# Página do processo 5000481-10.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000481-10.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000481-10.2017.8.21.0069
# Processando registro 89/329...
# Página do processo 5000477-31.2021.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000477-31.2021.8.21.0069
# Processando registro 90/329...
# Página do processo 5000477-02.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000477-02.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000477-02.2019.8.21.0069
# Processando registro 91/329...
# Página do processo 5000467-26.2017.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 22.02 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000467-26.2017.8.21.0069
# Processando registro 92/329...
# Página do processo 5000458-35.2015.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000458-35.2015.8.21.0069
# Processando registro 93/329...
# Página do processo 5000457-74.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000457-74.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000457-74.2020.8.21.0069
# Processando registro 94/329...
# Página do processo 5000457-11.2019.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000457-11.2019.8.21.0069
# Processando registro 95/329...
# Página do processo 5000450-09.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000450-09.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000450-09.2025.8.21.0069
# Processando registro 96/329...
# Página do processo 5000443-95.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000443-95.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000443-95.2017.8.21.0069
# Processando registro 97/329...
# Página do processo 5000441-91.2018.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000441-91.2018.8.21.0069
# Processando registro 98/329...
# Página do processo 5000439-92.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000439-92.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000439-92.2016.8.21.0069
# Processando registro 99/329...
# Página do processo 5000439-19.2021.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000439-19.2021.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000439-19.2021.8.21.0069
# Processando registro 100/329...
# Página do processo 5000437-59.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000437-59.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000437-59.2015.8.21.0069
# Processando registro 101/329...
# Página do processo 5000435-84.2018.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000435-84.2018.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000435-84.2018.8.21.0069
# Processando registro 102/329...
# Página do processo 5000435-55.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000435-55.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000435-55.2016.8.21.0069
# Processando registro 103/329...
# Página do processo 5000434-41.2014.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000434-41.2014.8.21.0069
# Processando registro 104/329...
# Página do processo 5000433-85.2016.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000433-85.2016.8.21.0069
# Processando registro 105/329...
# Página do processo 5000433-80.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000433-80.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000433-80.2019.8.21.0069
# Processando registro 106/329...
# Página do processo 5000429-09.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000429-09.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000429-09.2020.8.21.0069
# Processando registro 107/329...
# Página do processo 5000424-55.2018.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000424-55.2018.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000424-55.2018.8.21.0069
# Processando registro 108/329...
# Página do processo 5000423-07.2017.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000423-07.2017.8.21.0069
# Processando registro 109/329...
# Página do processo 5000421-42.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000421-42.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000421-42.2014.8.21.0069
# Processando registro 110/329...
# Página do processo 5000416-73.2021.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000416-73.2021.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000416-73.2021.8.21.0069
# Processando registro 111/329...
# Página do processo 5000415-30.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000415-30.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000415-30.2017.8.21.0069
# Processando registro 112/329...
# Página do processo 5000413-60.2017.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000413-60.2017.8.21.0069
# Processando registro 113/329...
# Página do processo 5000407-82.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000407-82.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000407-82.2019.8.21.0069
# Processando registro 114/329...
# Página do processo 5000399-42.2018.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000399-42.2018.8.21.0069
# Processando registro 115/329...
# Página do processo 5000399-03.2022.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000399-03.2022.8.21.0069
# Processando registro 116/329...
# Página do processo 5000397-72.2018.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 49.60 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000397-72.2018.8.21.0069
# Processando registro 117/329...
# Página do processo 5000396-14.2023.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000396-14.2023.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000396-14.2023.8.21.0069
# Processando registro 118/329...
# Página do processo 5000395-10.2015.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000395-10.2015.8.21.0069
# Processando registro 119/329...
# Página do processo 5000393-35.2018.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000393-35.2018.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000393-35.2018.8.21.0069
# Processando registro 120/329...
# Página do processo 5000391-07.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000391-07.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000391-07.2014.8.21.0069
# Processando registro 121/329...
# Página do processo 5000385-82.2023.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000385-82.2023.8.21.0069
# Processando registro 122/329...
# Página do processo 5000384-34.2022.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000384-34.2022.8.21.0069
# Processando registro 123/329...
# Página do processo 5000383-54.2019.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000383-54.2019.8.21.0069
# Processando registro 124/329...
# Página do processo 5000379-90.2014.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000379-90.2014.8.21.0069
# Processando registro 125/329...
# Página do processo 5000379-17.2019.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 68.87 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000379-17.2019.8.21.0069
# Processando registro 126/329...
# Página do processo 5000378-32.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000378-32.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000378-32.2019.8.21.0069
# Processando registro 127/329...
# Página do processo 5000373-78.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000373-78.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000373-78.2017.8.21.0069
# Processando registro 128/329...
# Página do processo 5000369-12.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000369-12.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000369-12.2015.8.21.0069
# Processando registro 129/329...
# Página do processo 5000366-18.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000366-18.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000366-18.2019.8.21.0069
# Processando registro 130/329...
# Página do processo 5000363-73.2013.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000363-73.2013.8.21.0069
# Processando registro 131/329...
# Página do processo 5000363-34.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000363-34.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000363-34.2017.8.21.0069
# Processando registro 132/329...
# Página do processo 5000361-06.2013.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000361-06.2013.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000361-06.2013.8.21.0069
# Processando registro 133/329...
# Página do processo 5000354-91.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000354-91.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000354-91.2025.8.21.0069
# Processando registro 134/329...
# Página do processo 5000353-48.2021.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000353-48.2021.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000353-48.2021.8.21.0069
# Processando registro 135/329...
# Página do processo 5000353-09.2025.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000353-09.2025.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000353-09.2025.8.21.0069
# Processando registro 136/329...
# Página do processo 5000351-93.2012.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000351-93.2012.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000351-93.2012.8.21.0069
# Processando registro 137/329...
# Página do processo 5000351-54.2016.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000351-54.2016.8.21.0069
# Processando registro 138/329...
# Página do processo 5000346-95.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000346-95.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000346-95.2017.8.21.0069
# Processando registro 139/329...
# Página do processo 5000327-31.2013.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000327-31.2013.8.21.0069
# Processando registro 140/329...
# Página do processo 5000323-18.2018.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000323-18.2018.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000323-18.2018.8.21.0069
# Processando registro 141/329...
# Página do processo 5000321-14.2019.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000321-14.2019.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000321-14.2019.8.21.0069
# Processando registro 142/329...
# Página do processo 5000315-46.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000315-46.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000315-46.2015.8.21.0069
# Processando registro 143/329...
# Página do processo 5000315-12.2016.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000315-12.2016.8.21.0069
# Processando registro 144/329...
# Página do processo 5000311-67.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000311-67.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000311-67.2019.8.21.0069
# Processando registro 145/329...
# Página do processo 5000311-14.2012.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000311-14.2012.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000311-14.2012.8.21.0069
# Processando registro 146/329...
# Página do processo 5000303-51.2023.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000303-51.2023.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000303-51.2023.8.21.0069
# Processando registro 147/329...
# Página do processo 5000295-79.2020.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000295-79.2020.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000295-79.2020.8.21.0069
# Processando registro 148/329...
# Página do processo 5000293-07.2023.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000293-07.2023.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000293-07.2023.8.21.0069
# Processando registro 149/329...
# Página do processo 5000291-28.2009.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000291-28.2009.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000291-28.2009.8.21.0069
# Processando registro 150/329...
# Página do processo 5000285-06.2018.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000285-06.2018.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000285-06.2018.8.21.0069
# Processando registro 151/329...
# Página do processo 5000283-89.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000283-89.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000283-89.2025.8.21.0069
# Processando registro 152/329...
# Página do processo 5000283-36.2018.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 24.86 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000283-36.2018.8.21.0069
# Processando registro 153/329...
# Página do processo 5000281-81.2009.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000281-81.2009.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000281-81.2009.8.21.0069
# Processando registro 154/329...
# Página do processo 5000281-03.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000281-03.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000281-03.2017.8.21.0069
# Processando registro 155/329...
# Página do processo 5000278-77.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000278-77.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000278-77.2019.8.21.0069
# Processando registro 156/329...
# Página do processo 5000277-68.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000277-68.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000277-68.2014.8.21.0069
# Processando registro 157/329...
# Página do processo 5000277-34.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000277-34.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000277-34.2015.8.21.0069
# Processando registro 158/329...
# Página do processo 5000275-40.2010.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000275-40.2010.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000275-40.2010.8.21.0069
# Processando registro 159/329...
# Página do processo 5000274-16.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000274-16.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000274-16.2014.8.21.0069
# Processando registro 160/329...
# Página do processo 5000272-07.2018.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000272-07.2018.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000272-07.2018.8.21.0069
# Processando registro 161/329...
# Página do processo 5000271-56.2017.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000271-56.2017.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000271-56.2017.8.21.0069
# Processando registro 162/329...
# Página do processo 5000267-97.2009.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000267-97.2009.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000267-97.2009.8.21.0069
# Processando registro 163/329...
# Página do processo 5000261-17.2014.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000261-17.2014.8.21.0069
# Processando registro 164/329...
# Página do processo 5000259-08.2018.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000259-08.2018.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000259-08.2018.8.21.0069
# Processando registro 165/329...
# Página do processo 5000257-77.2014.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000257-77.2014.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000257-77.2014.8.21.0069
# Processando registro 166/329...
# Página do processo 5000257-48.2012.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000257-48.2012.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000257-48.2012.8.21.0069
# Processando registro 167/329...
# Página do processo 5000256-24.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000256-24.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000256-24.2016.8.21.0069
# Processando registro 168/329...
# Página do processo 5000247-67.2013.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000247-67.2013.8.21.0069
# Processando registro 169/329...
# Página do processo 5000247-62.2016.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000247-62.2016.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000247-62.2016.8.21.0069
# Processando registro 170/329...
# Página do processo 5000241-89.2015.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000241-89.2015.8.21.0069
# Processando registro 171/329...
# Página do processo 5000235-58.2010.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000235-58.2010.8.21.0069
# Processando registro 172/329...
# Página do processo 5000233-78.2016.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000233-78.2016.8.21.0069
# Processando registro 173/329...
# Página do processo 5000227-52.2008.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000227-52.2008.8.21.0069
# Processando registro 174/329...
# Página do processo 5000225-77.2011.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000225-77.2011.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000225-77.2011.8.21.0069
# Processando registro 175/329...
# Página do processo 5000223-39.2013.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000223-39.2013.8.21.0069
# Processando registro 176/329...
# Página do processo 5000221-93.2018.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000221-93.2018.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000221-93.2018.8.21.0069
# Processando registro 177/329...
# Página do processo 5000221-40.2011.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000221-40.2011.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000221-40.2011.8.21.0069
# Processando registro 178/329...
# Página do processo 5000221-25.2020.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000221-25.2020.8.21.0069
# Processando registro 179/329...
# Página do processo 5000219-60.2017.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000219-60.2017.8.21.0069
# Processando registro 180/329...
# Página do processo 5000217-90.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000217-90.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000217-90.2017.8.21.0069
# Processando registro 181/329...
# Página do processo 5000217-56.2018.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000217-56.2018.8.21.0069
# Processando registro 182/329...
# Página do processo 5000215-38.2008.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000215-38.2008.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000215-38.2008.8.21.0069
# Processando registro 183/329...
# Página do processo 5000211-49.2018.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000211-49.2018.8.21.0069
# Processando registro 184/329...
# Página do processo 5000209-31.2008.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000209-31.2008.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000209-31.2008.8.21.0069
# Processando registro 185/329...
# Página do processo 5000208-46.2008.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000208-46.2008.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000208-46.2008.8.21.0069
# Processando registro 186/329...
# Página do processo 5000207-80.2016.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000207-80.2016.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000207-80.2016.8.21.0069
# Processando registro 187/329...
# Página do processo 5000205-86.2011.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000205-86.2011.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000205-86.2011.8.21.0069
# Processando registro 188/329...
# Página do processo 5000205-18.2013.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000205-18.2013.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000205-18.2013.8.21.0069
# Processando registro 189/329...
# Página do processo 5000201-83.2010.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000201-83.2010.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000201-83.2010.8.21.0069
# Processando registro 190/329...
# Página do processo 5000200-54.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000200-54.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000200-54.2017.8.21.0069
# Processando registro 191/329...
# Página do processo 5000199-50.2009.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000199-50.2009.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000199-50.2009.8.21.0069
# Processando registro 192/329...
# Página do processo 5000199-06.2016.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000199-06.2016.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000199-06.2016.8.21.0069
# Processando registro 193/329...
# Página do processo 5000197-94.2020.8.21.0069  carregada com sucesso.
# ...
# Processando registro 266/329...
# Página do processo 5000088-80.2020.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000088-80.2020.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000088-80.2020.8.21.0069
# Processando registro 267/329...
# Página do processo 5000087-13.2011.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000087-13.2011.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000087-13.2011.8.21.0069
# Processando registro 268/329...
# Página do processo 5000083-63.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000083-63.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000083-63.2017.8.21.0069
# Processando registro 269/329...
# Página do processo 5000079-65.2013.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 29.74 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000079-65.2013.8.21.0069
# Processando registro 270/329...
# Página do processo 5000079-36.2011.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000079-36.2011.8.21.0069
# Processando registro 271/329...
# Página do processo 5000077-46.2023.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000077-46.2023.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000077-46.2023.8.21.0069
# Processando registro 272/329...
# Página do processo 5000076-86.2008.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 30.00 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000076-86.2008.8.21.0069
# Processando registro 273/329...
# Página do processo 5000076-18.2010.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000076-18.2010.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000076-18.2010.8.21.0069
# Processando registro 274/329...
# Página do processo 5000075-57.2015.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000075-57.2015.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000075-57.2015.8.21.0069
# Processando registro 275/329...
# Página do processo 5000075-18.2019.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000075-18.2019.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000075-18.2019.8.21.0069
# Processando registro 276/329...
# Página do processo 5000071-98.2007.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000071-98.2007.8.21.0069
# Processando registro 277/329...
# Página do processo 5000069-60.2009.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000069-60.2009.8.21.0069
# Processando registro 278/329...
# Página do processo 5000069-35.2024.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000069-35.2024.8.21.0069
# Processando registro 279/329...
# Página do processo 5000069-16.2016.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000069-16.2016.8.21.0069
# Processando registro 280/329...
# Página do processo 5000068-85.2003.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000068-85.2003.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000068-85.2003.8.21.0069
# Processando registro 281/329...
# Página do processo 5000066-18.2003.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000066-18.2003.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000066-18.2003.8.21.0069
# Processando registro 282/329...
# Página do processo 5000065-86.2010.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000065-86.2010.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000065-86.2010.8.21.0069
# Processando registro 283/329...
# Página do processo 5000063-14.2013.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000063-14.2013.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000063-14.2013.8.21.0069
# Processando registro 284/329...
# Página do processo 5000061-92.2023.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000061-92.2023.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000061-92.2023.8.21.0069
# Processando registro 285/329...
# Página do processo 5000059-54.2025.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000059-54.2025.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000059-54.2025.8.21.0069
# Processando registro 286/329...
# Página do processo 5000057-89.2022.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000057-89.2022.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000057-89.2022.8.21.0069
# Processando registro 287/329...
# Página do processo 5000057-46.2009.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000057-46.2009.8.21.0069
# Processando registro 288/329...
# Página do processo 5000057-07.2013.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000057-07.2013.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000057-07.2013.8.21.0069
# Processando registro 289/329...
# Página do processo 5000051-44.2006.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000051-44.2006.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000051-44.2006.8.21.0069
# Processando registro 290/329...
# Página do processo 5000051-34.2012.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000051-34.2012.8.21.0069
# Processando registro 291/329...
# Página do processo 5000050-49.2012.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000050-49.2012.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000050-49.2012.8.21.0069
# Processando registro 292/329...
# Página do processo 5000050-15.2013.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000050-15.2013.8.21.0069
# Processando registro 293/329...
# Página do processo 5000049-98.2011.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 53.03 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000049-98.2011.8.21.0069
# Processando registro 294/329...
# Página do processo 5000049-15.2022.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000049-15.2022.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000049-15.2022.8.21.0069
# Processando registro 295/329...
# Página do processo 5000047-65.2010.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000047-65.2010.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000047-65.2010.8.21.0069
# Processando registro 296/329...
# Página do processo 5000047-40.2025.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000047-40.2025.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000047-40.2025.8.21.0069
# Processando registro 297/329...
# Página do processo 5000044-76.2011.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000044-76.2011.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000044-76.2011.8.21.0069
# Processando registro 298/329...
# Página do processo 5000043-28.2010.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000043-28.2010.8.21.0069
# Processando registro 299/329...
# Página do processo 5000041-53.2013.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000041-53.2013.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000041-53.2013.8.21.0069
# Processando registro 300/329...
# Página do processo 5000038-45.2006.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000038-45.2006.8.21.0069
# Processando registro 301/329...
# Página do processo 5000038-06.2010.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000038-06.2010.8.21.0069
# Processando registro 302/329...
# Página do processo 5000035-12.2014.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000035-12.2014.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000035-12.2014.8.21.0069
# Processando registro 303/329...
# Página do processo 5000035-07.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000035-07.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000035-07.2017.8.21.0069
# Processando registro 304/329...
# Página do processo 5000031-91.2022.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000031-91.2022.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000031-91.2022.8.21.0069
# Processando registro 305/329...
# Página do processo 5000031-82.2008.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 38.34 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000031-82.2008.8.21.0069
# Processando registro 306/329...
# Página do processo 5000027-30.2017.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000027-30.2017.8.21.0069
# Processando registro 307/329...
# Página do processo 5000025-70.2011.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000025-70.2011.8.21.0069
# Processando registro 308/329...
# Página do processo 5000025-51.2003.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000025-51.2003.8.21.0069
# Processando registro 309/329...
# Página do processo 5000025-07.2010.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000025-07.2010.8.21.0069
# Processando registro 310/329...
# Página do processo 5000021-62.2013.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000021-62.2013.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000021-62.2013.8.21.0069
# Processando registro 311/329...
# Página do processo 5000021-23.2017.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000021-23.2017.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000021-23.2017.8.21.0069
# Processando registro 312/329...
# Página do processo 5000021-14.2003.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000021-14.2003.8.21.0069
# Processando registro 313/329...
# Página do processo 5000021-09.2006.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 50.62 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000021-09.2006.8.21.0069
# Processando registro 314/329...
# Página do processo 5000018-15.2010.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000018-15.2010.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000018-15.2010.8.21.0069
# Processando registro 315/329...
# Página do processo 5000016-06.2014.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000016-06.2014.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000016-06.2014.8.21.0069
# Processando registro 316/329...
# Página do processo 5000015-07.2003.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: PDF mais recente tem diferença de 42.87 segundos da timestamp. Não será renomeado.
# Erro gravado na planilha para o processo 5000015-07.2003.8.21.0069
# Processando registro 317/329...
# Página do processo 5000013-56.2011.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000013-56.2011.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000013-56.2011.8.21.0069
# Processando registro 318/329...
# Página do processo 5000011-67.2003.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000011-67.2003.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000011-67.2003.8.21.0069
# Processando registro 319/329...
# Página do processo 5000011-18.2013.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000011-18.2013.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000011-18.2013.8.21.0069
# Processando registro 320/329...
# Página do processo 5000010-43.2007.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000010-43.2007.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000010-43.2007.8.21.0069
# Processando registro 321/329...
# Página do processo 5000009-87.2009.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000009-87.2009.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000009-87.2009.8.21.0069
# Processando registro 322/329...
# Página do processo 5000007-97.2021.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000007-97.2021.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000007-97.2021.8.21.0069
# Processando registro 323/329...
# Página do processo 5000007-30.2003.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000007-30.2003.8.21.0069
# Processando registro 324/329...
# Página do processo 5000007-20.2009.8.21.0069 carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000007-20.2009.8.21.0069
# Processando registro 325/329...
# Página do processo 5000003-75.2012.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000003-75.2012.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000003-75.2012.8.21.0069
# Processando registro 326/329...
# Página do processo 5000003-51.2007.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000003-51.2007.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000003-51.2007.8.21.0069
# Processando registro 327/329...
# Página do processo 5000001-85.2024.8.21.0069  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000001-85.2024.8.21.0069 .pdf
# Texto da petição gravado na planilha para o processo 5000001-85.2024.8.21.0069
# Processando registro 328/329...
# Página do processo 5000001-81.2007.8.21.0069 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Downloads\5000001-81.2007.8.21.0069.pdf
# Texto da petição gravado na planilha para o processo 5000001-81.2007.8.21.0069
# Processando registro 329/329...
# Página do processo 5000001-32.2017.8.21.0069  carregada com sucesso.
# Erro ao baixar petição: Nenhuma petição encontrada.
# Erro gravado na planilha para o processo 5000001-32.2017.8.21.0069
# Todos os registros foram processados!
# Total de registros processados: 329

# %%
#Gera lista de pendentes, do tipo de processo definido

with sqlite3.connect("urcaciv.db") as conn:
    df_pendentes = pd.read_sql_query(
        #f"SELECT * FROM {perfil} WHERE tipo = '{tipo_processo}' AND pet IS NULL", conn
        f"SELECT * FROM {perfil} WHERE pet IS NULL", conn
    )
df_pendentes = df_pendentes["num_processo"].tolist()

print(f"Total de processos pendentes: {len(df_pendentes)}")
# Out:
# Total de processos pendentes: 363

# %%
#EXECUTA! Pega as últimas petições

i=0
for processo in df_pendentes:
    df_pendentes.remove(processo)
    i += 1
    print(f"Baixando petição {i} de {len(df_pendentes)}")
    baixa_peticao_processo(navegador, processo)
# Out:
# Baixando petição 1 de 362
# Página do processo 5327143-98.2024.8.21.0001 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5327143-98.2024.8.21.0001.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5327143-98.2024.8.21.0001.pdf
# Baixando petição 2 de 361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       6 i += 1
#       7 print(f"Baixando petição {i} de {len(df_pendentes)}")
# ----> 8 baixa_peticao_processo(navegador, processo)
#
# Cell In[7], line 225, in baixa_peticao_processo(navegador, processo)
#     223 def baixa_peticao_processo(navegador, processo):
#     224     navegador.switch_to.default_content()
# --> 225     eproc.entrar_no_processo(navegador, processo)
#     227     with sqlite3.connect("urcaciv.db") as conn:
#     228         evento_id, texto_peticao = pega_ultima_peticao(navegador, processo)
#
# File d:\Douglas\Reps\UNICA\eproc_driver\eproc.py:220, in entrar_no_processo(driver, processo)
#     218 driver.find_element(By.NAME, "txtNumProcessoPesquisaRapida").send_keys(processo)
#     219 time.sleep(1)
# --> 220 driver.find_element(By.CSS_SELECTOR, ".d-none .btn-pesquisar > .material-icons").click()
#     221 time.sleep(1)
#     222 # Aguarda até que o body esteja presente, indicando que a página carregou
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:120, in WebElement.click(self)
#     112 def click(self) -> None:
#     113     """Clicks the element.
#     114
#     115     Example:
#    (...)    118     >>> element.click()
#     119     """
# --> 120     self._execute(Command.CLICK_ELEMENT)
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\selenium\webdriver\remote\webelement.py:573, in WebElement._execute(self, command, params)
#     571     params = {}
#     572 params["id"] = self._id
# --> 573 return self._parent.execute(command, params)
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.execute(self, driver_command, params)
#     452     elif "sessionId" not in params:
#     453         params["sessionId"] = self.session_id
# --> 455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
#     458     self.error_handler.check_response(response)
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:406, in RemoteConnection.execute(self, command, params)
#     404 trimmed = self._trim_large_entries(params)
#     405 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 406 return self._request(command_info[0], url, body=data)
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:430, in RemoteConnection._request(self, method, url, body)
#     427     body = None
#     429 if self._client_config.keep_alive:
# --> 430     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     431     statuscode = response.status
#     432 else:
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\Douglas\Reps\UNICA\.venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Percorre todos os arquivos PDF na pasta de downloads

arquivos_pdf = glob.glob(os.path.join(pasta_downloads, "*.pdf"))

with sqlite3.connect("urcaciv.db") as conn:
    for caminho_pdf in arquivos_pdf:
        nome_arquivo = os.path.basename(caminho_pdf)
        num_processo, _ = os.path.splitext(nome_arquivo)
        try:
            texto_pet = extrair_texto_pdf(caminho_pdf)
        except Exception as e:
            print(f"Erro ao extrair texto de {nome_arquivo}: {e}")
            continue

        # Atualiza o campo 'pet' no banco de dados
        with closing(conn.cursor()) as cursor:
            cursor.execute(
                f"UPDATE {perfil} SET pet = ? WHERE num_processo = ?",
                (texto_pet, num_processo)
            )
            conn.commit()

        # Se o texto preenchido tem mais de 10 caracteres, apaga o arquivo
        if texto_pet and len(texto_pet) > 10:
            try:
                os.remove(caminho_pdf)
                print(f"Arquivo {nome_arquivo} removido após atualização.")
            except Exception as e:
                print(f"Erro ao remover {nome_arquivo}: {e}")
# Out:
# Erro ao extrair texto de 5010525-06.2014.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5029522-66.2016.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5032142-12.2020.8.21.0001 .pdf: EOF marker not found
# Erro ao extrair texto de 5103385-11.2023.8.21.0001.pdf: startxref not found
