# %%
# Importações e setup

#from selenium import webdriver
from seleniumwire import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException, WebDriverException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException

#Bibliotecas de Sistema
from datetime import datetime
from datetime import timedelta
from datetime import date
from datetime import timezone
import time
import re
import csv
import os
import requests
import psutil
from bs4 import BeautifulSoup
from eproc_driver import eproc as eproc
import sqlite3
from pathlib import Path
import io
import pandas as pd
from contextlib import closing
from sympy import false
from pydoc import text
from sympy import true
import PyPDF2
import glob

#bibliotecas de configuração
import pyotp
import configparser
import keyring

#bibliotecas de automação
import pyperclip
import pyautogui

#Bibliotecas de IA
from gemini import gemini as gemini
import ollama



# DEBUG, sim ou não
debug = False

# %%
# Definição de perfil e tipo de processo

#perfil = "SRD1CIV"
#perfil = "CAN1CIV"
#perfil = "GDO1CIV"
perfil = "STM1CIV"
#perfil = "SRO2CR"
#perfil = "POA08FZFC"


tipo_processo = "EXECUÇÃO FISCAL"

print("Perfil escolhido:", perfil)
print("Tipo de Processo:", tipo_processo)

#pasta_downloads = r"C:\Users\dodonin\Downloads"
pasta_downloads = r"D:\Douglas\Reps\UNICA\PDFs"
# Out:
# Perfil escolhido: STM1CIV
# Tipo de Processo: EXECUÇÃO FISCAL

# %%
# Inicia o navegador, loga no perfil escolhido

if debug:
    print(f"[DEBUG] pasta_downloads: {pasta_downloads}")

navegador = eproc.novo_browser(pasta_downloads)

if debug:
    print("[DEBUG] Navegador iniciado.")

#configura variáveis
username = "dodonin"
password = keyring.get_password("eproc", username)
pyotop_code = "GJRGIYTCGBSGKYTEHE2TOZRUGFQTMMRQ"

#eproc.login_no_eproc_tj(navegador, username, password, pyotop_code)
eproc.login_no_eproc(navegador, username, password, pyotop_code)

if debug:
    print("[DEBUG] Login realizado.")

# Entra no perfil da Vara
eproc.entrar_no_perfil(navegador, perfil)

if debug:
    print(f"[DEBUG] Entrou no perfil: {perfil}")
# Out:
# Driver do Eproc importado
# Perfil carregado: STM1CIV

# %%
# Define funções

def pega_tabela_pagina(dados_tabela):
    tabela = navegador.find_element(By.ID, "tabelaLocalizadores")
    linhas = tabela.find_elements(By.TAG_NAME, "tr")[1:]  # Ignora o cabeçalho
    lastpage = false
    while lastpage == false:
        for linha in linhas:
            # Aguarda o carregamento do tbody da tabela antes de processar as linhas
            WebDriverWait(navegador, 10).until(
                EC.presence_of_element_located((By.XPATH, "//table[@id='tabelaLocalizadores']/tbody"))
            )
            colunas = linha.find_elements(By.TAG_NAME, "td")
            if len(colunas) >= 4:
                # Pega as três primeiras colunas e também a última
                dados_tabela.append([
                    colunas[1].text.split('\n')[0],
                    colunas[2].text.split('\n')[0],
                    colunas[3].text.split('\n')[0],
                    colunas[-1].text.split('\n')[0]
                ])
            
            lastpage = true

def pega_ultima_peticao(navegador, num_processo):
    """
    Localiza a última petição ("PET") disponível no processo informado,
    captura a requisição real feita pelo navegador (Selenium Wire) para baixar o PDF
    e salva o arquivo localmente.

    Parâmetros:
        navegador     -> instância do Selenium Wire WebDriver já autenticada no eproc.
        num_processo  -> número do processo (será usado no nome do PDF).

    Retorna:
        (evento_id, caminho_pdf) se o download foi bem-sucedido.
        (None, None) caso não haja petição ou falha no download.
    """
    import os
    import requests
    from selenium.webdriver.common.by import By
    import glob

    # === 1. Coleta todos os eventos do processo ===
    documentos_eventos = []
    eventos = navegador.find_elements(By.CLASS_NAME, "td-evento")

    for evento in eventos:
        # ID do elemento que identifica o documento
        doc_id = evento.get_dom_attribute("id")

        # Sobe até a linha da tabela e pega o número do evento
        tr_element = evento.find_element(By.XPATH, "./ancestor::tr")
        evento_id = tr_element.find_element(By.XPATH, './td[2]').text
        evento_id = ''.join(filter(str.isdigit, evento_id))  # mantém só números

        # Verifica se é documento tipo PET (Petição)
        try:
            infra_link = evento.find_element(By.XPATH, ".//*[contains(@class, 'infraLinkDoc')]")
            data_nome = infra_link.get_attribute("data-nome")
        except Exception:
            data_nome = None

        documentos_eventos.append((doc_id, data_nome, evento_id))

    # === 2. Filtra apenas documentos do tipo PET ===
    documentos_eventos_filtrados = [item for item in documentos_eventos if item[1] == "PET"]

    if not documentos_eventos_filtrados:
        print("❌ Nenhuma petição encontrada.")
        return None, None

    # === 3. Pega a petição mais recente (maior evento_id) ===
    documentos_eventos_filtrados.sort(key=lambda x: int(x[2]), reverse=True)
    documento_requerido = documentos_eventos_filtrados[0]
    evento_id = documento_requerido[2]

    # Caminho onde o PDF será salvo
    caminho_pdf = os.path.join(pasta_downloads, f"{num_processo}.pdf")

    # Localiza o elemento do documento e o link
    elemento = navegador.find_element(By.ID, documento_requerido[0])
    link = elemento.find_element(By.XPATH, ".//*[contains(@class, 'infraLinkDoc')]")

    # Limpa histórico de requests para capturar apenas a próxima
    navegador.requests.clear()

    # Clica no link para gerar a requisição ao controlador.php
    link.click()
    
    # Aguarda o carregamento do preview/divBoxPreview para garantir que o clique gerou a requisição
    WebDriverWait(navegador, 10).until(
        EC.presence_of_element_located((By.ID, "divBoxPreview"))
    )
    time.sleep(2)  # Pequeno delay extra para garantir a requisição
    # Clica no botão "open-button" para abrir o documento em nova janela/aba
    # Vai para a aba que foi aberta
    if len(navegador.window_handles) > 1:
        navegador.switch_to.window(navegador.window_handles[-1])
    try:
        timestamp_download = datetime.now().isoformat()
        navegador.find_element(By.TAG_NAME, 'body').send_keys('\t\t\n')
        time.sleep(1)
    except Exception as e:
        print("Botão 'open-button' não encontrado ou erro ao clicar:", e)
    # Fecha a nova aba/janela aberta pelo botão "open-button"
    if len(navegador.window_handles) > 1:
        # Fecha todas as abas, menos a primeira
        while len(navegador.window_handles) > 1:
            navegador.switch_to.window(navegador.window_handles[-1])
            navegador.close()
        navegador.switch_to.window(navegador.window_handles[0])
    # === 4. Procura o PDF mais recente na pasta de downloads ===

    arquivos_pdf = glob.glob(os.path.join(pasta_downloads, "*.pdf"))
    if not arquivos_pdf:
        print("❌ Nenhum PDF encontrado na pasta de downloads.")
        return evento_id, None

    # Encontra o PDF mais recente
    pdf_mais_recente = max(arquivos_pdf, key=os.path.getmtime)
    tempo_modificacao = os.path.getmtime(pdf_mais_recente)
    tempo_modificacao_dt = datetime.fromtimestamp(tempo_modificacao)
    tempo_diff = abs((tempo_modificacao_dt - datetime.fromisoformat(timestamp_download)).total_seconds())

    if tempo_diff <= 10:
        # Move o arquivo para o caminho_pdf
        os.makedirs(os.path.dirname(caminho_pdf), exist_ok=True)
        os.replace(pdf_mais_recente, caminho_pdf)
        print(f"PDF renomeado e salvo em: {caminho_pdf}")

        return evento_id, caminho_pdf
    else:
        print(f"PDF mais recente tem diferença de {tempo_diff:.2f} segundos da timestamp. Não será renomeado.")
        return evento_id, None

def extrair_texto_pdf(caminho_pdf):
    with open(caminho_pdf, 'rb') as arquivo:
        leitor = PyPDF2.PdfReader(arquivo)
        texto = ""
        for pagina in leitor.pages:
            texto += pagina.extract_text()
    return texto

def pega_texto_documento(navegador, documento):
    WebDriverWait(navegador, 20).until(
        EC.presence_of_element_located((By.ID, documento))
    )
    # 1. Localizar o elemento pelo ID
    elemento = navegador.find_element(By.ID, documento)
    # 2. Criar ActionChains para executar o mouse over
    actions = ActionChains(navegador)
    # Rolar a página para o elemento antes de mover o mouse
    navegador.execute_script("arguments[0].scrollIntoView(true); window.scrollBy(0, -150);", elemento)
    # Faz o mouseover em cima do texto link infraLinkDocumento do elemento
    link_doc = elemento.find_element(By.XPATH, ".//*[contains(@class, 'infraLinkDoc')]")
    actions.move_to_element(link_doc).perform()
    # 3. Aguardar para o hover ter efeito
    time.sleep(5)
    
    # Verifica se há uma div com a classe 'divBoxPreview' visível na página
    overlays = navegador.find_elements(By.ID, "divBoxPreview")
    visiveis = [div for div in overlays if div.is_displayed()]

    conteudo = ""
    if visiveis:
        div = overlays[0]
        # Move o foco para a div
        ActionChains(navegador).move_to_element(div).click().perform()
        # Aguarda carregar o conteúdo (ajuste o tempo se necessário)
        time.sleep(1)
        # Seleciona o texto
        conteudo = navegador.find_element(By.ID, "divBoxPreview").text
        # Clica no botão de fechar o preview, se existir
        btn_close = navegador.find_element(By.ID, "divClosePreview")
        btn_close.click()    
        time.sleep(3)

    else:
        print("Erro ao recuperar o documento")
    return conteudo

def ollama_resumo(pedido):    
    pergunta_gemma = "Considere o seguinte pedido." \
    f"{pedido}" \
    "Resuma, da maneira mais objetiva possível, o pedido. Não mencione dados pessoais, como nomes, números de documento, números de processo, valores, etc. " \
    "O resumo deve ser genérico e breve (uma frase apenas, com o mínimo de palavras possível). " \
    "Se tiver mais de um pedido, retorne uma frase para cada um." \

    resumo = ollama.chat(
        model="cnmoro/gemma3-gaia-ptbr-4b:q8_0",
        messages=[{'role': 'user', 'content': f'{pergunta_gemma}'}],    
    )

    return(resumo['message']['content'])

def verifica_tipos_de_pedidos(pedido, lista_de_pedidos):

    print("========== Verificando se é um caso de uso conhecido... ==========")
    pergunta_gemma = "Considere a seguinte lista de pedidos:" \
    f"{lista_de_pedidos}" \
    f"É possível dizer que o pedido '{pedido}' pode ser adequadamente descrito por um item dessa lista?." \
    "Se sim, retorne APENAS o texto EXATO do resumo do pedido correspondente na lista. Se não, retorne APENAS o texto 'Não'."

    resumo = ollama.chat(
        model="cnmoro/gemma3-gaia-ptbr-4b:q8_0",
        messages=[{'role': 'user', 'content': f'{pergunta_gemma}'}],    
    )

    return(resumo['message']['content'])

def baixa_peticao_processo(navegador, processo):
    navegador.switch_to.default_content()
    eproc.entrar_no_processo(navegador, processo)

    with sqlite3.connect("urcaciv.db") as conn:
        try:
            evento_id, texto_peticao = pega_ultima_peticao(navegador, processo)

            print(f"========== TEXTO DA PETIÇÃO ==========")
            print(texto_peticao)


            with closing(conn.cursor()) as cursor:
                cursor.execute(
                    f"UPDATE {perfil} SET pet = ? WHERE num_processo = ?",
                    (texto_peticao, processo)
                )
                conn.commit()
        except Exception as e:
            print("Erro ao processar petição:", e)
            with closing(conn.cursor()) as cursor:
                cursor.execute(
                    f"UPDATE {perfil} SET pet = ? WHERE num_processo = ?",
                    ("ERRO", processo)
                )
                conn.commit()

# %%
#EXECUTA! Pega as últimas petições

#Gera lista de pendentes, do tipo de processo definido

with sqlite3.connect("urcaciv.db") as conn:
    df_pendentes = pd.read_sql_query(
        #f"SELECT * FROM {perfil} WHERE tipo = '{tipo_processo}' AND pet IS NULL", conn
        f"SELECT * FROM {perfil} WHERE pet IS NULL", conn
    )
df_pendentes = df_pendentes["num_processo"].tolist()

print(f"Total de processos pendentes: {len(df_pendentes)}")

i=0
for processo in df_pendentes:
    i += 1
    print(f"Baixando petição {i} de {len(df_pendentes)}")
    baixa_peticao_processo(navegador, processo)
# Out:
# Total de processos pendentes: 107
# Baixando petição 1 de 107
# Página do processo 5001058-46.2019.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 168.66 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 2 de 107
# Página do processo 5039411-53.2022.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 179.17 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 3 de 107
# Página do processo 5038105-49.2022.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 196.58 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 4 de 107
# Página do processo 5038100-27.2022.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 213.17 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 5 de 107
# Página do processo 5035518-20.2023.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 230.86 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 6 de 107
# Página do processo 5035210-81.2023.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 248.59 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 7 de 107
# Página do processo 5034747-71.2025.8.21.0027 carregada com sucesso.
# ❌ Nenhuma petição encontrada.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 8 de 107
# Página do processo 5032707-19.2025.8.21.0027 carregada com sucesso.
# ❌ Nenhuma petição encontrada.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 9 de 107
# Página do processo 5032102-44.2023.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 277.72 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 10 de 107
# Página do processo 5031067-49.2023.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 296.24 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 11 de 107
# Página do processo 5029820-04.2021.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 307.74 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 12 de 107
# Página do processo 5029008-59.2021.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 324.07 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 13 de 107
# Página do processo 5028225-67.2021.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 343.15 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 14 de 107
# Página do processo 5023617-26.2021.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 360.90 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 15 de 107
# Página do processo 5014220-74.2020.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 381.01 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 16 de 107
# Página do processo 5010965-40.2022.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 400.68 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 17 de 107
# Página do processo 5010813-94.2019.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 412.76 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 18 de 107
# Página do processo 5008151-94.2018.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 428.75 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 19 de 107
# Página do processo 5007915-45.2018.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 443.24 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 20 de 107
# Página do processo 5007914-60.2018.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 463.59 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 21 de 107
# Página do processo 5007315-24.2018.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 484.99 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 22 de 107
# Página do processo 5005215-62.2019.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 503.51 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 23 de 107
# Página do processo 5002710-40.2015.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 517.67 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 24 de 107
# Página do processo 5002617-14.2014.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 537.50 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 25 de 107
# Página do processo 5002412-19.2013.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 559.26 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 26 de 107
# Página do processo 5002408-79.2013.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 579.18 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 27 de 107
# Página do processo 5002307-08.2014.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 596.77 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 28 de 107
# Página do processo 5002252-18.2018.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 617.62 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 29 de 107
# Página do processo 5002202-31.2014.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 631.89 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 30 de 107
# Página do processo 5002137-36.2014.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 652.65 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 31 de 107
# Página do processo 5002120-97.2014.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 11.29 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 32 de 107
# Página do processo 5001910-46.2014.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 31.20 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 33 de 107
# Página do processo 5001422-62.2012.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 50.12 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 34 de 107
# Página do processo 5001346-38.2012.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 72.29 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 35 de 107
# Página do processo 5001100-42.2012.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 83.70 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 36 de 107
# Página do processo 5001080-17.2013.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5001080-17.2013.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5001080-17.2013.8.21.0027 .pdf
# Baixando petição 37 de 107
# Página do processo 5001070-41.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5001070-41.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5001070-41.2011.8.21.0027 .pdf
# Baixando petição 38 de 107
# Página do processo 5001058-46.2019.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 12.39 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 39 de 107
# Página do processo 5001047-46.2021.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5001047-46.2021.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5001047-46.2021.8.21.0027 .pdf
# Baixando petição 40 de 107
# Página do processo 5001040-11.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5001040-11.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5001040-11.2008.8.21.0027 .pdf
# Baixando petição 41 de 107
# Página do processo 5001034-04.2008.8.21.0027  carregada com sucesso.
# Erro ao processar petição: [WinError 32] O arquivo já está sendo usado por outro processo: 'D:\\Douglas\\Reps\\UNICA\\PDFs\\82_PET1.pdf' -> 'D:\\Douglas\\Reps\\UNICA\\PDFs\\5001034-04.2008.8.21.0027 .pdf'
# Baixando petição 42 de 107
# Página do processo 5001024-57.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5001024-57.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5001024-57.2008.8.21.0027 .pdf
# Baixando petição 43 de 107
# Página do processo 5001007-79.2012.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5001007-79.2012.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5001007-79.2012.8.21.0027 .pdf
# Baixando petição 44 de 107
# Página do processo 5001004-66.2008.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 11.77 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 45 de 107
# Página do processo 5000998-54.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000998-54.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000998-54.2011.8.21.0027 .pdf
# Baixando petição 46 de 107
# Página do processo 5000983-07.2019.8.21.0027 carregada com sucesso.
# Erro ao processar petição: [WinError 32] O arquivo já está sendo usado por outro processo: 'D:\\Douglas\\Reps\\UNICA\\PDFs\\97_PET1.pdf' -> 'D:\\Douglas\\Reps\\UNICA\\PDFs\\5000983-07.2019.8.21.0027.pdf'
# Baixando petição 47 de 107
# Página do processo 5000971-08.2010.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000971-08.2010.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000971-08.2010.8.21.0027 .pdf
# Baixando petição 48 de 107
# Página do processo 5000954-74.2007.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000954-74.2007.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000954-74.2007.8.21.0027.pdf
# Baixando petição 49 de 107
# Página do processo 5000951-22.2007.8.21.0027  carregada com sucesso.
# ❌ Nenhuma petição encontrada.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 50 de 107
# Página do processo 5000951-17.2010.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000951-17.2010.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000951-17.2010.8.21.0027 .pdf
# Baixando petição 51 de 107
# Página do processo 5000926-04.2010.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000926-04.2010.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000926-04.2010.8.21.0027 .pdf
# Baixando petição 52 de 107
# Página do processo 5000896-37.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000896-37.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000896-37.2008.8.21.0027 .pdf
# Baixando petição 53 de 107
# Página do processo 5000892-34.2007.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000892-34.2007.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000892-34.2007.8.21.0027.pdf
# Baixando petição 54 de 107
# Página do processo 5000889-30.2017.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000889-30.2017.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000889-30.2017.8.21.0027 .pdf
# Baixando petição 55 de 107
# Página do processo 5000864-66.2007.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000864-66.2007.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000864-66.2007.8.21.0027 .pdf
# Baixando petição 56 de 107
# Página do processo 5000850-48.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000850-48.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000850-48.2008.8.21.0027 .pdf
# Baixando petição 57 de 107
# Página do processo 5000845-16.2014.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000845-16.2014.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000845-16.2014.8.21.0027 .pdf
# Baixando petição 58 de 107
# Página do processo 5000838-34.2008.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000838-34.2008.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000838-34.2008.8.21.0027.pdf
# Baixando petição 59 de 107
# Página do processo 5000834-21.2013.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000834-21.2013.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000834-21.2013.8.21.0027 .pdf
# Baixando petição 60 de 107
# Página do processo 5000827-97.2011.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 13.23 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 61 de 107
# Página do processo 5000819-23.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000819-23.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000819-23.2011.8.21.0027 .pdf
# Baixando petição 62 de 107
# Página do processo 5000818-43.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000818-43.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000818-43.2008.8.21.0027 .pdf
# Baixando petição 63 de 107
# Página do processo 5000804-59.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000804-59.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000804-59.2008.8.21.0027 .pdf
# Baixando petição 64 de 107
# Página do processo 5000788-95.2014.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000788-95.2014.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000788-95.2014.8.21.0027 .pdf
# Baixando petição 65 de 107
# Página do processo 5000781-06.2014.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000781-06.2014.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000781-06.2014.8.21.0027 .pdf
# Baixando petição 66 de 107
# Página do processo 5000778-90.2010.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000778-90.2010.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000778-90.2010.8.21.0027.pdf
# Baixando petição 67 de 107
# Página do processo 5000767-61.2010.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000767-61.2010.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000767-61.2010.8.21.0027 .pdf
# Baixando petição 68 de 107
# Página do processo 5000763-92.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000763-92.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000763-92.2008.8.21.0027 .pdf
# Baixando petição 69 de 107
# Página do processo 5000759-84.2010.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000759-84.2010.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000759-84.2010.8.21.0027 .pdf
# Baixando petição 70 de 107
# Página do processo 5000728-30.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000728-30.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000728-30.2011.8.21.0027 .pdf
# Baixando petição 71 de 107
# Página do processo 5000711-13.2019.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 14.88 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 72 de 107
# Página do processo 5000707-83.2013.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000707-83.2013.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000707-83.2013.8.21.0027.pdf
# Baixando petição 73 de 107
# Página do processo 5000693-70.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000693-70.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000693-70.2011.8.21.0027 .pdf
# Baixando petição 74 de 107
# Página do processo 5000668-52.2014.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000668-52.2014.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000668-52.2014.8.21.0027 .pdf
# Baixando petição 75 de 107
# Página do processo 5000662-50.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000662-50.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000662-50.2011.8.21.0027 .pdf
# Baixando petição 76 de 107
# Página do processo 5000649-17.2012.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000649-17.2012.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000649-17.2012.8.21.0027 .pdf
# Baixando petição 77 de 107
# Página do processo 5000640-94.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000640-94.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000640-94.2008.8.21.0027 .pdf
# Baixando petição 78 de 107
# Página do processo 5000629-89.2013.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000629-89.2013.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000629-89.2013.8.21.0027 .pdf
# Baixando petição 79 de 107
# Página do processo 5000605-95.2012.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000605-95.2012.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000605-95.2012.8.21.0027 .pdf
# Baixando petição 80 de 107
# Página do processo 5000579-34.2011.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000579-34.2011.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000579-34.2011.8.21.0027.pdf
# Baixando petição 81 de 107
# Página do processo 5000563-80.2011.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000563-80.2011.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000563-80.2011.8.21.0027 .pdf
# Baixando petição 82 de 107
# Página do processo 5000563-12.2013.8.21.0027 carregada com sucesso.
# PDF mais recente tem diferença de 14.21 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 83 de 107
# Página do processo 5000561-18.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000561-18.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000561-18.2008.8.21.0027 .pdf
# Baixando petição 84 de 107
# Página do processo 5000516-82.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000516-82.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000516-82.2006.8.21.0027 .pdf
# Baixando petição 85 de 107
# Página do processo 5000489-69.2024.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000489-69.2024.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000489-69.2024.8.21.0027.pdf
# Baixando petição 86 de 107
# Página do processo 5000477-85.2006.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000477-85.2006.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000477-85.2006.8.21.0027.pdf
# Baixando petição 87 de 107
# Página do processo 5000452-18.2019.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000452-18.2019.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000452-18.2019.8.21.0027 .pdf
# Baixando petição 88 de 107
# Página do processo 5000444-46.2016.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000444-46.2016.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000444-46.2016.8.21.0027 .pdf
# Baixando petição 89 de 107
# Página do processo 5000414-50.2012.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000414-50.2012.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000414-50.2012.8.21.0027 .pdf
# Baixando petição 90 de 107
# Página do processo 5000399-13.2014.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000399-13.2014.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000399-13.2014.8.21.0027 .pdf
# Baixando petição 91 de 107
# Página do processo 5000367-86.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000367-86.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000367-86.2006.8.21.0027 .pdf
# Baixando petição 92 de 107
# Página do processo 5000349-94.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000349-94.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000349-94.2008.8.21.0027 .pdf
# Baixando petição 93 de 107
# Página do processo 5000348-80.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000348-80.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000348-80.2006.8.21.0027 .pdf
# Baixando petição 94 de 107
# Página do processo 5000341-88.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000341-88.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000341-88.2006.8.21.0027 .pdf
# Baixando petição 95 de 107
# Página do processo 5000332-29.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000332-29.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000332-29.2006.8.21.0027 .pdf
# Baixando petição 96 de 107
# Página do processo 5000326-94.2021.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000326-94.2021.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000326-94.2021.8.21.0027 .pdf
# Baixando petição 97 de 107
# Página do processo 5000306-31.2006.8.21.0027  carregada com sucesso.
# PDF mais recente tem diferença de 12.98 segundos da timestamp. Não será renomeado.
# ========== TEXTO DA PETIÇÃO ==========
# None
# Baixando petição 98 de 107
# Página do processo 5000284-70.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000284-70.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000284-70.2006.8.21.0027 .pdf
# Baixando petição 99 de 107
# Página do processo 5000266-78.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000266-78.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000266-78.2008.8.21.0027 .pdf
# Baixando petição 100 de 107
# Página do processo 5000232-93.2014.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000232-93.2014.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000232-93.2014.8.21.0027.pdf
# Baixando petição 101 de 107
# Página do processo 5000196-85.2013.8.21.0027 carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000196-85.2013.8.21.0027.pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000196-85.2013.8.21.0027.pdf
# Baixando petição 102 de 107
# Página do processo 5000186-85.2006.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000186-85.2006.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000186-85.2006.8.21.0027 .pdf
# Baixando petição 103 de 107
# Página do processo 5000170-29.2009.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000170-29.2009.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000170-29.2009.8.21.0027 .pdf
# Baixando petição 104 de 107
# Página do processo 5000128-14.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000128-14.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000128-14.2008.8.21.0027 .pdf
# Baixando petição 105 de 107
# Página do processo 5000093-54.2008.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000093-54.2008.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000093-54.2008.8.21.0027 .pdf
# Baixando petição 106 de 107
# Página do processo 5000053-09.2007.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000053-09.2007.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000053-09.2007.8.21.0027 .pdf
# Baixando petição 107 de 107
# Página do processo 5000041-43.2017.8.21.0027  carregada com sucesso.
# PDF renomeado e salvo em: D:\Douglas\Reps\UNICA\PDFs\5000041-43.2017.8.21.0027 .pdf
# ========== TEXTO DA PETIÇÃO ==========
# D:\Douglas\Reps\UNICA\PDFs\5000041-43.2017.8.21.0027 .pdf

# %%
# Percorre todos os arquivos PDF na pasta de downloads

arquivos_pdf = glob.glob(os.path.join(pasta_downloads, "*.pdf"))

with sqlite3.connect("urcaciv.db") as conn:
    for caminho_pdf in arquivos_pdf:
        nome_arquivo = os.path.basename(caminho_pdf)
        num_processo, _ = os.path.splitext(nome_arquivo)
        try:
            texto_pet = extrair_texto_pdf(caminho_pdf)
        except Exception as e:
            print(f"Erro ao extrair texto de {nome_arquivo}: {e}")
            continue

        # Atualiza o campo 'pet' no banco de dados
        with closing(conn.cursor()) as cursor:
            cursor.execute(
                f"UPDATE {perfil} SET pet = ? WHERE num_processo = ?",
                (texto_pet, num_processo)
            )
            conn.commit()

        # Se o texto preenchido tem mais de 10 caracteres, apaga o arquivo
        if texto_pet and len(texto_pet) > 10:
            try:
                os.remove(caminho_pdf)
                print(f"Arquivo {nome_arquivo} removido após atualização.")
            except Exception as e:
                print(f"Erro ao remover {nome_arquivo}: {e}")
# Out:
# Erro ao extrair texto de 18_PET8.pdf: Cannot read an empty file
# Arquivo 249_PET1.pdf removido após atualização.
# Arquivo 5000041-43.2017.8.21.0027 .pdf removido após atualização.
# Arquivo 5000053-09.2007.8.21.0027 .pdf removido após atualização.
# Arquivo 5000093-54.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000128-14.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000170-29.2009.8.21.0027 .pdf removido após atualização.
# Arquivo 5000186-85.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000196-85.2013.8.21.0027.pdf removido após atualização.
# Arquivo 5000232-93.2014.8.21.0027.pdf removido após atualização.
# Arquivo 5000266-78.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000284-70.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000326-94.2021.8.21.0027 .pdf removido após atualização.
# Arquivo 5000332-29.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000341-88.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000348-80.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000349-94.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000367-86.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000399-13.2014.8.21.0027 .pdf removido após atualização.
# Arquivo 5000414-50.2012.8.21.0027 .pdf removido após atualização.
# Arquivo 5000444-46.2016.8.21.0027 .pdf removido após atualização.
# Arquivo 5000452-18.2019.8.21.0027 .pdf removido após atualização.
# Arquivo 5000477-85.2006.8.21.0027.pdf removido após atualização.
# Arquivo 5000489-69.2024.8.21.0027.pdf removido após atualização.
# Arquivo 5000516-82.2006.8.21.0027 .pdf removido após atualização.
# Arquivo 5000561-18.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000563-80.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5000579-34.2011.8.21.0027.pdf removido após atualização.
# Arquivo 5000605-95.2012.8.21.0027 .pdf removido após atualização.
# Arquivo 5000629-89.2013.8.21.0027 .pdf removido após atualização.
# Arquivo 5000640-94.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000649-17.2012.8.21.0027 .pdf removido após atualização.
# Arquivo 5000662-50.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5000668-52.2014.8.21.0027 .pdf removido após atualização.
# Arquivo 5000693-70.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5000707-83.2013.8.21.0027.pdf removido após atualização.
# Arquivo 5000728-30.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5000759-84.2010.8.21.0027 .pdf removido após atualização.
# Arquivo 5000763-92.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000767-61.2010.8.21.0027 .pdf removido após atualização.
# Arquivo 5000778-90.2010.8.21.0027.pdf removido após atualização.
# Arquivo 5000781-06.2014.8.21.0027 .pdf removido após atualização.
# Arquivo 5000788-95.2014.8.21.0027 .pdf removido após atualização.
# Arquivo 5000804-59.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000818-43.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000819-23.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5000834-21.2013.8.21.0027 .pdf removido após atualização.
# Arquivo 5000838-34.2008.8.21.0027.pdf removido após atualização.
# Arquivo 5000845-16.2014.8.21.0027 .pdf removido após atualização.
# Arquivo 5000850-48.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000864-66.2007.8.21.0027 .pdf removido após atualização.
# Arquivo 5000889-30.2017.8.21.0027 .pdf removido após atualização.
# Arquivo 5000892-34.2007.8.21.0027.pdf removido após atualização.
# Arquivo 5000896-37.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5000926-04.2010.8.21.0027 .pdf removido após atualização.
# Arquivo 5000951-17.2010.8.21.0027 .pdf removido após atualização.
# Arquivo 5000954-74.2007.8.21.0027.pdf removido após atualização.
# Arquivo 5000971-08.2010.8.21.0027 .pdf removido após atualização.
# Arquivo 5000998-54.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5001007-79.2012.8.21.0027 .pdf removido após atualização.
# Arquivo 5001024-57.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5001040-11.2008.8.21.0027 .pdf removido após atualização.
# Arquivo 5001047-46.2021.8.21.0027 .pdf removido após atualização.
# Arquivo 5001070-41.2011.8.21.0027 .pdf removido após atualização.
# Arquivo 5001080-17.2013.8.21.0027 .pdf removido após atualização.
# Arquivo 5002727-08.2017.8.21.0027.pdf removido após atualização.
# Arquivo 5006288-06.2018.8.21.0027 .pdf removido após atualização.
# Erro ao extrair texto de 5010525-06.2014.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5012068-10.2015.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5012094-18.2009.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5019160-34.2018.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5029522-66.2016.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5032142-12.2020.8.21.0001 .pdf: EOF marker not found
# Erro ao extrair texto de 5033193-68.2014.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5035854-88.2012.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5074306-26.2019.8.21.0001.pdf: startxref not found
# Erro ao extrair texto de 5103385-11.2023.8.21.0001.pdf: startxref not found
# Arquivo 82_PET1.pdf removido após atualização.
